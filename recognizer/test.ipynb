# %%
from scipy.io import loadmat
from pathlib import Path
import mat73

# %%
ROOT_DIR = Path("..").resolve()

data_dict = mat73.loadmat(ROOT_DIR / "data" / "lsa64_positions.mat")

# %%
data_dict["db"].keys()
# Out:
# dict_keys(['class', 'hand_left_exist_in_frame', 'hand_positions_left', 'hand_positions_right', 'hand_right_exist_in_frame', 'repetition', 'subject'])

# %%
data_dict["db"]["repetition"]
# Out:
# [array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
#  array(2.),
#  array(3.),
#  array(4.),
#  array(5.),
#  array(1.),
# ...
